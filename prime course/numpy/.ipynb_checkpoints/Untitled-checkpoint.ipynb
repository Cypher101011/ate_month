# %% [markdown]
# #numpy data taypes

# %%
import numpy as np

# %% [markdown]
# array creation

# %%
a1 =np.array([1,2,3,4])
print("example 1:",a1)
a2=np.zeros((2,3))
print("examplet e2",a2)
# Out:
# example 1: [1 2 3 4]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 print("example 1:",a1)
#       3 a2=np.zeros((2,3))
# ----> 4 prit("examplet e2",a2)
#
# NameError: name 'prit' is not defined
