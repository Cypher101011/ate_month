# %%
import pandas as pd

# %% [markdown]
# seriesm

# %%
ser = pd.Series([1,2,3,4,5,6,7,8,9])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ser = pd.series([1,2,3,4,5,6,7,8,9])
#
# AttributeError: module 'pandas' has no attribute 'series'
