# %% [markdown]
# #numpy data taypes

# %%
import numpy as np

# %% [markdown]
# array creation

# %%
a1 =np.array([1,2,3,4])
print("example 1:",a1)
a2=np.zeros((2,3))
print("examplet e2",a2)
# Out:
# example 1: [1 2 3 4]
# examplet e2 [[0. 0. 0.]
#  [0. 0. 0.]]

# %% [markdown]
# array attributioe

# %%
a =npAAF.array([[1,2,3],[4,5,6]])
