# %%
import pandas as pd

# %%
df= pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          200 non-null    int64
#  1   Genre               200 non-null    object
#  2   Age                 200 non-null    int64
#  3   Annual_Income_(k$)  200 non-null    int64
#  4   Spending_Score      200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual_Income_(k$)  Spending_Score
# count  200.000000  200.000000          200.000000      200.000000
# mean   100.500000   38.850000           60.560000       50.200000
# std     57.879185   13.969007           26.264721       25.823522
# min      1.000000   18.000000           15.000000        1.000000
# 25%     50.750000   28.750000           41.500000       34.750000
# 50%    100.500000   36.000000           61.500000       50.000000
# 75%    150.250000   49.000000           78.000000       73.000000
# max    200.000000   70.000000          137.000000       99.000000

# %%
df.isnull()
# Out:
#      CustomerID  Genre    Age  Annual_Income_(k$)  Spending_Score
# 0         False  False  False               False           False
# 1         False  False  False               False           False
# 2         False  False  False               False           False
# 3         False  False  False               False           False
# 4         False  False  False               False           False
# ..          ...    ...    ...                 ...             ...
# 195       False  False  False               False           False
# 196       False  False  False               False           False
# 197       False  False  False               False           False
# 198       False  False  False               False           False
# 199       False  False  False               False           False
#
# [200 rows x 5 columns]

# %%
df.isnull().count()
# Out:
# CustomerID            200
# Genre                 200
# Age                   200
# Annual_Income_(k$)    200
# Spending_Score        200
# dtype: int64

# %%
df.isnull().sum()
# Out:
# CustomerID            0
# Genre                 0
# Age                   0
# Annual_Income_(k$)    0
# Spending_Score        0
# dtype: int64

# %%
df.dtypes
# Out:
# CustomerID             int64
# Genre                 object
# Age                    int64
# Annual_Income_(k$)     int64
# Spending_Score         int64
# dtype: object

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0           1    Male   19                  15              39
# 1           2    Male   21                  15              81
# 2           3  Female   20                  16               6
# 3           4  Female   23                  16              77
# 4           5  Female   31                  17              40

# %%
import pandas as pd
df=pd.read_csv("dirty_cafe_sales.csv")

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9667 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    7421 non-null   object
#  6   Location          6735 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: object(8)
# memory usage: 625.1+ KB

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
df.isin(['ERROR',"UNKNOWN",""]).sum()
# Out:
# Transaction ID        0
# Item                636
# Quantity            341
# Price Per Unit      354
# Total Spent         329
# Payment Method      599
# Location            696
# Transaction Date    301
# dtype: int64

# %%
pd.to_numeric(df["Quantity"],errors='coerce')
# Out:
# 0       2.0
# 1       4.0
# 2       4.0
# 3       2.0
# 4       2.0
#        ...
# 9995    2.0
# 9996    3.0
# 9997    4.0
# 9998    3.0
# 9999    3.0
# Name: Quantity, Length: 10000, dtype: float64

# %%
df['caluclated_total']=df['Quantity']* df['Price Per Unit']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/ops/array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %%
df.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df.plot()
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/plotting/_matplotlib/core.py:499, in MPLPlot.generate(self)
#     497 @final
#     498 def generate(self) -> None:
# ...

# %%
df["Quantity_num"]=pd.to_numeric(df["Quantity"],errors='coerce')

# %%
df["Price_num"]=pd.to_numeric(df["Price Per Unit"],errors='coerce')

# %%
df["Total_num"]=pd.to_numeric(df["Total Spent"],errors="coerce")

# %%
df[["Quantity", "Quantity_num", "Price Per Unit", "Price_num", "Total Spent", "Total_num"]].head(100)
# Out:
#    Quantity  Quantity_num Price Per Unit  Price_num Total Spent  Total_num
# 0         2           2.0            2.0        2.0         4.0        4.0
# 1         4           4.0            3.0        3.0        12.0       12.0
# 2         4           4.0            1.0        1.0       ERROR        NaN
# 3         2           2.0            5.0        5.0        10.0       10.0
# 4         2           2.0            2.0        2.0         4.0        4.0
# ..      ...           ...            ...        ...         ...        ...
# 95        3           3.0            5.0        5.0        15.0       15.0
# 96        5           5.0            5.0        5.0        25.0       25.0
# 97        4           4.0            2.0        2.0         8.0        8.0
# 98        4           4.0            3.0        3.0        12.0       12.0
# 99        4           4.0            2.0        2.0         8.0        8.0
#
# [100 rows x 6 columns]

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date  Quantity_num  Price_num  Total_num
# 0  Takeaway       2023-09-08           2.0        2.0        4.0
# 1  In-store       2023-05-16           4.0        3.0       12.0
# 2  In-store       2023-07-19           4.0        1.0        NaN
# 3   UNKNOWN       2023-04-27           2.0        5.0       10.0
# 4  In-store       2023-06-11           2.0        2.0        4.0

# %%
for col in ['Item','Payment Method','Location']:
    df[col]=(df[col]
        .str.strip()
        .str.lower()
        .replace({"error":None,"unknown":None,"":None})
                )

# %%
df.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  coffee        2            2.0         4.0     credit card
# 1    TXN_4977031    cake        4            3.0        12.0            cash
# 2    TXN_4271903  cookie        4            1.0       ERROR     credit card
# 3    TXN_7034554   salad        2            5.0        10.0            None
# 4    TXN_3160411  coffee        2            2.0         4.0  digital wallet
#
#    Location Transaction Date  Quantity_num  Price_num  Total_num
# 0  takeaway       2023-09-08           2.0        2.0        4.0
# 1  in-store       2023-05-16           4.0        3.0       12.0
# 2  in-store       2023-07-19           4.0        1.0        NaN
# 3      None       2023-04-27           2.0        5.0       10.0
# 4  in-store       2023-06-11           2.0        2.0        4.0

# %%
df[["Quantity_num","Price_num","Total_num"]].describe()
# Out:
#        Quantity_num    Price_num    Total_num
# count   9521.000000  9467.000000  9498.000000
# mean       3.028463     2.949984     8.924352
# std        1.419007     1.278450     6.009919
# min        1.000000     1.000000     1.000000
# 25%        2.000000     2.000000     4.000000
# 50%        3.000000     3.000000     8.000000
# 75%        4.000000     4.000000    12.000000
# max        5.000000     5.000000    25.000000

# %%
(df["Quantity_num"] * df["Price_num"] == df["Total_num"]).value_counts()
# Out:
# True     8544
# False    1456
# Name: count, dtype: int64

# %%
df["Total_num"] = df["Quantity_num"] * df["Price_num"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9862 non-null   object
#  3   Price Per Unit    9821 non-null   object
#  4   Total Spent       9827 non-null   object
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9841 non-null   object
#  8   Quantity_num      9521 non-null   float64
#  9   Price_num         9467 non-null   float64
#  10  Total_num         9006 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 859.5+ KB

# %%
df['Quantity']=df['Quantity_num']

# %%
df['Price Per Unit']=df['Price_num']

# %%
df['Total Spent']=df['Total_num']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9006 non-null   float64
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9841 non-null   object
#  8   Quantity_num      9521 non-null   float64
#  9   Price_num         9467 non-null   float64
#  10  Total_num         9006 non-null   float64
# dtypes: float64(6), object(5)
# memory usage: 859.5+ KB

# %%
df['Total Spent']=df['Total Spent'].fillna(df['Quantity']*df['Price Per Unit'])

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    coffee       2.0             2.0          4.0
# 1       TXN_4977031      cake       4.0             3.0         12.0
# 2       TXN_4271903    cookie       4.0             1.0          4.0
# 3       TXN_7034554     salad       2.0             5.0         10.0
# 4       TXN_3160411    coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    coffee       2.0             2.0          4.0
# 9996    TXN_9659401       NaN       3.0             NaN          NaN
# 9997    TXN_5255387    coffee       4.0             2.0          8.0
# 9998    TXN_7695629    cookie       3.0             NaN          NaN
# 9999    TXN_6170729  sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date  Quantity_num  Price_num  \
# ...

# %%
df.drop(columns=['Quantity_num'],inplace=True)

# %%
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  coffee       2.0             2.0          4.0
# 1    TXN_4977031    cake       4.0             3.0         12.0
# 2    TXN_4271903  cookie       4.0             1.0          4.0
# 3    TXN_7034554   salad       2.0             5.0         10.0
# 4    TXN_3160411  coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date  Price_num  Total_num
# 0     credit card  takeaway       2023-09-08        2.0        4.0
# 1            cash  in-store       2023-05-16        3.0       12.0
# 2     credit card  in-store       2023-07-19        1.0        4.0
# 3            None      None       2023-04-27        5.0       10.0
# 4  digital wallet  in-store       2023-06-11        2.0        4.0

# %%
df.drop(columns=['Price_num','Total_num'],inplace=True)

# %%
df.head()
# Out:
#   Transaction ID    Item  Quantity  Price Per Unit  Total Spent  \
# 0    TXN_1961373  coffee       2.0             2.0          4.0
# 1    TXN_4977031    cake       4.0             3.0         12.0
# 2    TXN_4271903  cookie       4.0             1.0          4.0
# 3    TXN_7034554   salad       2.0             5.0         10.0
# 4    TXN_3160411  coffee       2.0             2.0          4.0
#
#    Payment Method  Location Transaction Date
# 0     credit card  takeaway       2023-09-08
# 1            cash  in-store       2023-05-16
# 2     credit card  in-store       2023-07-19
# 3            None      None       2023-04-27
# 4  digital wallet  in-store       2023-06-11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9006 non-null   float64
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 625.1+ KB

# %%
df['Transaction ID']=(
    df['Transaction ID'].str.strip())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9006 non-null   float64
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 625.1+ KB

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.histogram()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5623/4220749527.py in ?()
# ----> 1 df.histogram()
#
# ~/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'histogram'

# %%
df['Payment Method']=(
    df['Payment Method']
    .str.strip()
    .str.lower()
    .replace({'error':None,'':None}))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  object
#  1   Item              9031 non-null   object
#  2   Quantity          9521 non-null   float64
#  3   Price Per Unit    9467 non-null   float64
#  4   Total Spent       9006 non-null   float64
#  5   Payment Method    6822 non-null   object
#  6   Location          6039 non-null   object
#  7   Transaction Date  9841 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 625.1+ KB

# %%
df['Transaction ID']=df['Transaction ID'].str.strip()

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    coffee       2.0             2.0          4.0
# 1       TXN_4977031      cake       4.0             3.0         12.0
# 2       TXN_4271903    cookie       4.0             1.0          4.0
# 3       TXN_7034554     salad       2.0             5.0         10.0
# 4       TXN_3160411    coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    coffee       2.0             2.0          4.0
# 9996    TXN_9659401       NaN       3.0             NaN          NaN
# 9997    TXN_5255387    coffee       4.0             2.0          8.0
# 9998    TXN_7695629    cookie       3.0             NaN          NaN
# 9999    TXN_6170729  sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        credit card  takeaway       2023-09-08
# ...

# %%
df['Payment Method']=(df['Payment Method']
                      .str.lower()
                      .str.strip()
                      .replace({None:'','unknown':''}))

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    coffee       2.0             2.0          4.0
# 1       TXN_4977031      cake       4.0             3.0         12.0
# 2       TXN_4271903    cookie       4.0             1.0          4.0
# 3       TXN_7034554     salad       2.0             5.0         10.0
# 4       TXN_3160411    coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9995    TXN_7672686    coffee       2.0             2.0          4.0
# 9996    TXN_9659401       NaN       3.0             NaN          NaN
# 9997    TXN_5255387    coffee       4.0             2.0          8.0
# 9998    TXN_7695629    cookie       3.0             NaN          NaN
# 9999    TXN_6170729  sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        credit card  takeaway       2023-09-08
# ...

# %%
import numpy as np
df['Payment Method'].fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 import numpy as np
# ----> 2 df['Payment Method'].fillna()
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:7293, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    7286         if ctr <= ref_count:
#    7287             warnings.warn(
#    7288                 _chained_assignment_warning_method_msg,
#    7289                 FutureWarning,
#    7290                 stacklevel=2,
#    7291             )
# -> 7293 value, method = validate_fillna_kwargs(value, method)
#    7294 if method is not None:
#    7295     warnings.warn(
#    7296         f"{type(self).__name__}.fillna with 'method' is deprecated and "
#    7297         "will raise in a future version. Use obj.ffill() or obj.bfill() "
#    (...)
#    7300         stacklevel=find_stack_level(),
# ...

# %%
np
# Out:
# <module 'numpy' from '/home/a/anaconda3/lib/python3.13/site-packages/numpy/__init__.py'>

# %%
df =df.replace('',np.nan ,regex=True)

# %%
df=df.dropna(subset=["Item"])

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    coffee       2.0             2.0          4.0
# 1       TXN_4977031      cake       4.0             3.0         12.0
# 2       TXN_4271903    cookie       4.0             1.0          4.0
# 3       TXN_7034554     salad       2.0             5.0         10.0
# 4       TXN_3160411    coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9993    TXN_4766549  smoothie       2.0             4.0          8.0
# 9995    TXN_7672686    coffee       2.0             2.0          4.0
# 9997    TXN_5255387    coffee       4.0             2.0          8.0
# 9998    TXN_7695629    cookie       3.0             NaN          NaN
# 9999    TXN_6170729  sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        credit card  takeaway       2023-09-08
# ...

# %%
df.describe()
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  8611.000000     8552.000000  8147.000000
# mean      3.029846        2.951766     8.945870
# std       1.422212        1.276793     5.995391
# min       1.000000        1.000000     1.000000
# 25%       2.000000        2.000000     4.000000
# 50%       3.000000        3.000000     8.000000
# 75%       4.000000        4.000000    12.000000
# max       5.000000        5.000000    25.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9031 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    9031 non-null   object
#  1   Item              9031 non-null   object
#  2   Quantity          8611 non-null   float64
#  3   Price Per Unit    8552 non-null   float64
#  4   Total Spent       8147 non-null   float64
#  5   Payment Method    6154 non-null   object
#  6   Location          5448 non-null   object
#  7   Transaction Date  8888 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 635.0+ KB

# %%
df.loc[:,'Location']=df['Location'].fillna('unknown')

# %%
df
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0       TXN_1961373    coffee       2.0             2.0          4.0
# 1       TXN_4977031      cake       4.0             3.0         12.0
# 2       TXN_4271903    cookie       4.0             1.0          4.0
# 3       TXN_7034554     salad       2.0             5.0         10.0
# 4       TXN_3160411    coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9993    TXN_4766549  smoothie       2.0             4.0          8.0
# 9995    TXN_7672686    coffee       2.0             2.0          4.0
# 9997    TXN_5255387    coffee       4.0             2.0          8.0
# 9998    TXN_7695629    cookie       3.0             NaN          NaN
# 9999    TXN_6170729  sandwich       3.0             4.0         12.0
#
#       Payment Method  Location Transaction Date
# 0        credit card  takeaway       2023-09-08
# ...

# %%
df['Transaction Date'].dtype
# Out:
# dtype('O')

# %%
df.loc[:, 'Transaction Date'] = pd.to_datetime(
    df['Transaction Date'],
    format='%Y-%m-%d',
    errors='coerce'
)

# %%
df.loc[:,'Transaction Date']=pd.to_datetime(df['Transaction Date'],
    infer_datetime_format=True)
# Out:
# /tmp/ipykernel_5623/3906176774.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df.loc[:,'Transaction Date']=pd.to_datetime(df['Transaction Date'],

# %%
d
